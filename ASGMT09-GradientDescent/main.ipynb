# %% [raw]
# Implement Gradient Descent Algorithm to find the local minima of a function.
#
# For example, find the local minima of the function y=(x+3)² starting from the point x=2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def function(x):
    return (x+3)**2

def derivative(x):
    return 2*(x+3)

# %%
points=[]

def gradient_descent(starting_x,learning_rate,no_of_iterations):
    x=starting_x
    for i in range(no_of_iterations):
        points.append(x)
        print(f"Iteration :{i+1} , x= {x} , y= {function(x)}")
        grad=derivative(x)
        x=x-(grad*learning_rate)
    return x

# %%
starting_x=2
learning_rate=0.1
no_of_iterations=100

min_x=gradient_descent(starting_x,learning_rate,no_of_iterations)
print(f"Local Minima at x= {min_x}")
# Out:
# Iteration :1 , x= 2 , y= 25
# Iteration :2 , x= 1.0 , y= 16.0
# Iteration :3 , x= 0.19999999999999996 , y= 10.240000000000002
# Iteration :4 , x= -0.44000000000000017 , y= 6.553599999999998
# Iteration :5 , x= -0.9520000000000001 , y= 4.194304
# Iteration :6 , x= -1.3616000000000001 , y= 2.6843545599999996
# Iteration :7 , x= -1.6892800000000001 , y= 1.7179869183999996
# Iteration :8 , x= -1.951424 , y= 1.099511627776
# Iteration :9 , x= -2.1611392 , y= 0.7036874417766399
# Iteration :10 , x= -2.32891136 , y= 0.4503599627370493
# Iteration :11 , x= -2.463129088 , y= 0.28823037615171165
# Iteration :12 , x= -2.5705032704 , y= 0.1844674407370954
# Iteration :13 , x= -2.6564026163200003 , y= 0.11805916207174093
# Iteration :14 , x= -2.725122093056 , y= 0.07555786372591429
# Iteration :15 , x= -2.7800976744448 , y= 0.04835703278458515
# Iteration :16 , x= -2.82407813955584 , y= 0.030948500982134555
# Iteration :17 , x= -2.8592625116446717 , y= 0.019807040628566166
# ...

# %%
x_vals=np.linspace(-5,5,100)
y_vals=function(x_vals)

plt.plot(x_vals,y_vals,label="y=(x+3)**2")
plt.scatter(points,[function(point) for point in points],color="red", label="Gradient Descent Steps")
plt.title("Gradient Descent Optimisation")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()
